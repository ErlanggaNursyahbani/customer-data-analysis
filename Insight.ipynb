# %% [markdown]
# # 📊 Customer Financial Insights Report
#
# **Disusun oleh:** Erlangga Nursyahbani
# **Tujuan:** Menyajikan insight bisnis dari data keuangan pelanggan berdasarkan EDA yang telah dilakukan sebelumnya.
# **Dataset:** cleaned_customer_data_final.csv
# **Total pelanggan:** `100.000`
#
# ---
#
# ## Insight 1 – Distribusi Skor Kredit Pelanggan
#
# Mayoritas pelanggan berada pada kategori `Standard`, disusul oleh `Good`, lalu `Poor`. Ini memberikan gambaran umum tentang kualitas pelanggan dari sudut pandang skor kredit.

# %%
from IPython.display import Image, display
display(Image("./images/insight1_skor_kredit.png"))

# %% [markdown]
# ---
# # Insight 2 – Rata-rata Rasio Pemanfaatan Kredit
# Pelanggan dengan skor Poor cenderung memiliki rasio pemanfaatan kredit yang tinggi, yang bisa menjadi indikator risiko kegagalan pembayaran.

# %%
display(Image("./images/insight2_utilisasi_kredit.png"))

# %% [markdown]
# ---
# # Insight 3 – Hubungan EMI dan Pendapatan
# Terdapat pola bahwa pelanggan dengan pendapatan rendah dan EMI tinggi lebih banyak masuk kategori Poor. Ini memberikan sinyal penting untuk segmentasi risiko kredit.

# %%
display(Image("./images/insight3_emi_vs_income.png"))

# %% [markdown]
# ---
# # Insight 4 – Jumlah Keterlambatan Pembayaran
# Semakin buruk skor kredit, semakin tinggi jumlah keterlambatan pembayaran. Ini memperkuat korelasi antara keterlambatan dan evaluasi kredit.

# %%
display(Image("./images/insight4_delay_vs_score.png"))

# %% [markdown]
# ---
# # Insight 5 – Distribusi Skor Kredit per Pekerjaan
# Pekerjaan tertentu seperti High Skill Private dan Government lebih dominan memiliki skor kredit Good, sedangkan sektor informal atau Unemployed cenderung Poor.

# %%
display(Image("./images/insight5_score_per_occupation.png"))

# %% [markdown]
# ---
# ---
# # 📌 Kesimpulan Utama
# 1. Skor kredit pelanggan sangat dipengaruhi oleh rasio penggunaan kredit dan keterlambatan pembayaran.
#
# 2. EMI dan pendapatan dapat menjadi sinyal awal risiko gagal bayar.
#
# 3. Segmentasi pelanggan berdasarkan pekerjaan efektif untuk menentukan strategi pinjaman atau pemasaran produk keuangan.
